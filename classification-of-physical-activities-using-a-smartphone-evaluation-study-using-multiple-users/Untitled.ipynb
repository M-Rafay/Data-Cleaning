# %%
# All Includes

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf  # Version 1.0.0 (some previous versions are used in past commits)
from sklearn import metrics

import os

# %%
import pandas as pd

# %%
# Useful Constants

# Those are separate normalised input features for the neural network
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

# Output classes to learn how to classify
LABELS = [
    "WALKING", 
    "WALKING_UPSTAIRS", 
    "WALKING_DOWNSTAIRS", 
    "SITTING", 
    "STANDING", 
    "LAYING"
]

# %%
column_time_series = ['user-id','activity','timestamp', 'x-axis', 'y-axis', 'z-axis']
column_labels = ['user-id','activity','timestamp', 'label']

test_labels = pd.read_csv("test_labels.csv",header = None, names = column_labels)
test_time_series = pd.read_csv("test_time_series.csv",header = None, names = column_time_series)
train_labels = pd.read_csv("train_labels.csv",header = None, names = column_labels)
train_time_series = pd.read_csv("train_time_series.csv",header = None, names = column_time_series)

# %%
test_labels.head(5)
# Out:
#    user-id       activity                timestamp  label
# 0      NaN      timestamp                 UTC time  label
# 1  24339.0  1565110307041  2019-08-06T16:51:47.041    NaN
# 2  24349.0  1565110308043  2019-08-06T16:51:48.043    NaN
# 3  24359.0  1565110309046  2019-08-06T16:51:49.046    NaN
# 4  24369.0  1565110310048  2019-08-06T16:51:50.048    NaN

# %%
test_time_series.head(5)
# Out:
#                user-id                 activity timestamp  \
# NaN          timestamp                 UTC time  accuracy
# 24330.0  1565110306139  2019-08-06T16:51:46.139   unknown
# 24331.0  1565110306239  2019-08-06T16:51:46.239   unknown
# 24332.0  1565110306340  2019-08-06T16:51:46.340   unknown
# 24333.0  1565110306440  2019-08-06T16:51:46.440   unknown
#
#                       x-axis               y-axis              z-axis
# NaN                        x                    y                   z
# 24330.0   0.0342864990234375    -1.50445556640625   0.157623291015625
# 24331.0   0.4091644287109375   -1.038543701171875   0.030975341796875
# 24332.0  -0.2343902587890625    -0.98455810546875  0.1247711181640625
# 24333.0   0.2511138916015625  -0.7870025634765625     0.0548095703125

# %%
train_labels.head(5)
# Out:
#    user-id       activity                timestamp  label
# 0      NaN      timestamp                 UTC time  label
# 1  20589.0  1565109931087  2019-08-06T16:45:31.087      1
# 2  20599.0  1565109932090  2019-08-06T16:45:32.090      1
# 3  20609.0  1565109933092  2019-08-06T16:45:33.092      1
# 4  20619.0  1565109934094  2019-08-06T16:45:34.094      1

# %%
train_time_series.head(5)
# Out:
#                user-id                 activity timestamp  \
# NaN          timestamp                 UTC time  accuracy
# 20586.0  1565109930787  2019-08-06T16:45:30.787   unknown
# 20587.0  1565109930887  2019-08-06T16:45:30.887   unknown
# 20588.0  1565109930987  2019-08-06T16:45:30.987   unknown
# 20589.0  1565109931087  2019-08-06T16:45:31.087   unknown
#
#                       x-axis               y-axis               z-axis
# NaN                        x                    y                    z
# 20586.0  -0.0064849853515625  -0.9348602294921876  -0.0690460205078125
# 20587.0    -0.06646728515625    -1.01544189453125   0.0895538330078125
# 20588.0   -0.043487548828125  -1.0212554931640625       0.178466796875
# 20589.0   -0.053802490234375   -0.987701416015625   0.0689849853515625

# %%
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results
x_train = vectorize_sequences(train_time_series)
x_test = vectorize_sequences(test_time_series)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-f6520cb4e484> in <module>
#       5         results[i, sequence] = 1.
#       6     return results
# ----> 7 x_train = vectorize_sequences(train_time_series)
#       8 x_test = vectorize_sequences(test_time_series)
#
# <ipython-input-13-f6520cb4e484> in vectorize_sequences(sequences, dimension)
#       3     results = np.zeros((len(sequences), dimension))
#       4     for i, sequence in enumerate(sequences):
# ----> 5         results[i, sequence] = 1.
#       6     return results
#       7 x_train = vectorize_sequences(train_time_series)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
