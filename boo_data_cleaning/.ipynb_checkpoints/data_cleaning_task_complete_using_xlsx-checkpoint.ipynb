# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
header_names=["A","B"]


Book_Data_cleaning = pd.read_excel('Book_ Data_cleaning_Wasim_Bhai.xlsx', sheetname='Sheet1',header=None)

print("Column headings:")
print(Book_Data_cleaning.columns)
# Out:
# Column headings:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
Book_Data_cleaning=pd.DataFrame(Book_Data_cleaning)

# %%
Book_Data_cleaning=Book_Data_cleaning[1:]
Book_Data_cleaning
# Out:
#       0                                                  1    2  \
# 1   NaN                     Bus 6ESF001TB fails to operate  Bus
# 2   NaN                      Bus EAB001TB fails to operate  NaN
# 3   NaN                      Bus EAA001TB fails to operate  NaN
# 4   NaN                      Bus EAA001TB fails to operate  NaN
# 5   NaN                      Bus EAE001TB fails to operate  NaN
# 6   NaN                      Bus EAW001TB fails to operate  NaN
# 7   NaN                      Bus EAY001TB fails to operate  NaN
# 8   NaN                      Bus ECA001TB fails to operate  NaN
# 9   NaN                      Bus ECB001TB fails to operate  NaN
# 10  NaN                      Bus EDA001TB fails to operate  NaN
# 11  NaN                     Bus EDB001TB  fails to operate  NaN
# 12  NaN                      Bus EDG001TB fails to operate  NaN
# 13  NaN                      Bus EEA001TB fails to operate  NaN
# 14  NaN                                                NaN  NaN
# ...

# %%
Book_Data_cleaning.columns = ['A','B','C','D']

# %%
Book_Data_cleaning
# Out:
#       A                                                  B    C  \
# 1   NaN                     Bus 6ESF001TB fails to operate  Bus
# 2   NaN                      Bus EAB001TB fails to operate  NaN
# 3   NaN                      Bus EAA001TB fails to operate  NaN
# 4   NaN                      Bus EAA001TB fails to operate  NaN
# 5   NaN                      Bus EAE001TB fails to operate  NaN
# 6   NaN                      Bus EAW001TB fails to operate  NaN
# 7   NaN                      Bus EAY001TB fails to operate  NaN
# 8   NaN                      Bus ECA001TB fails to operate  NaN
# 9   NaN                      Bus ECB001TB fails to operate  NaN
# 10  NaN                      Bus EDA001TB fails to operate  NaN
# 11  NaN                     Bus EDB001TB  fails to operate  NaN
# 12  NaN                      Bus EDG001TB fails to operate  NaN
# 13  NaN                      Bus EEA001TB fails to operate  NaN
# 14  NaN                                                NaN  NaN
# ...

# %%
list_A=list(Book_Data_cleaning['B'])

# %%
list_C=list(Book_Data_cleaning['D'])
list_C
# Out:
# [nan,
#  nan,
#  ' fails to operate',
#  ' fails to operate',
#  ' fails to operate',
#  ' fails to operate',
#  ' fails to operate',
#  ' fails to operate',
#  ' fails to operate',
#  ' fails to operate',
#  ' fails to operate',
#  ' fails to operate',
#  ' fails to operate',
#  nan,
#  ' fails to start',
#  nan,
#  nan,
#  'unavailability due to test and maintenance',
#  ' fails to start',
#  ' fails to operate',
#  ' fails to operate(<1h）',
#  'unavailability due to test and maintenance',
#  ' fails to operate',
#  nan,
#  ' blockage',
#  ' blockage',
#  ' blockage',
#  ' blockage',
#  ' blockage',
#  ' blockage',
#  'spurious operation',
#  ' large external leakage',
#  'small external leakage ',
#  nan,
#  nan,
#  'refuses to open',
#  'refuses to open',
#  'refuses to open',
#  'refuses to open',
#  'refuses to open',
#  'refuses to open',
#  ' refuses to close',
#  ' spurious operation',
#  ' refuses to close',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
Book_Data_cleaning['B']
# Out:
# 1                         Bus 6ESF001TB fails to operate
# 2                          Bus EAB001TB fails to operate
# 3                          Bus EAA001TB fails to operate
# 4                          Bus EAA001TB fails to operate
# 5                          Bus EAE001TB fails to operate
# 6                          Bus EAW001TB fails to operate
# 7                          Bus EAY001TB fails to operate
# 8                          Bus ECA001TB fails to operate
# 9                          Bus ECB001TB fails to operate
# 10                         Bus EDA001TB fails to operate
# 11                        Bus EDB001TB  fails to operate
# 12                         Bus EDG001TB fails to operate
# 13                         Bus EEA001TB fails to operate
# 14                                                   NaN
# 15             Recirculation fan VCP001ZV fails to start
# 16      Recirculation fan VCP001ZV fails to operate(>1h）
# ...

# %%
# # i=0
# for item in list_C:
#      item='\'+item
# #     i=i+1

# %%
Book_Data_cleaning
# Out:
#       A                                                  B    C  \
# 1   NaN                     Bus 6ESF001TB fails to operate  Bus
# 2   NaN                      Bus EAB001TB fails to operate  NaN
# 3   NaN                      Bus EAA001TB fails to operate  NaN
# 4   NaN                      Bus EAA001TB fails to operate  NaN
# 5   NaN                      Bus EAE001TB fails to operate  NaN
# 6   NaN                      Bus EAW001TB fails to operate  NaN
# 7   NaN                      Bus EAY001TB fails to operate  NaN
# 8   NaN                      Bus ECA001TB fails to operate  NaN
# 9   NaN                      Bus ECB001TB fails to operate  NaN
# 10  NaN                      Bus EDA001TB fails to operate  NaN
# 11  NaN                     Bus EDB001TB  fails to operate  NaN
# 12  NaN                      Bus EDG001TB fails to operate  NaN
# 13  NaN                      Bus EEA001TB fails to operate  NaN
# 14  NaN                                                NaN  NaN
# ...

# %%
# Book_Data_cleaning['B'].iloc[i] = str(Book_Data_cleaning['B'].iloc[i]).replace(str(item),'')
# for item in list_C:
# #     item=str(item)
#     Book_Data_cleaning['B'] = Book_Data_cleaning['B'].replace('\(<1h）', '')
#     print(item)
for item in list_C:
#     item=str(item)
    
    print(item)
    Book_Data_cleaning['B'] = Book_Data_cleaning['B'].str.replace(str(item), "")
# Out:
# nan
# nan
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
# nan
#  fails to start
# nan
# nan
# unavailability due to test and maintenance
#  fails to start
#  fails to operate
#  fails to operate(<1h）
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-159-6d8db46d707d> in <module>()
#       8
#       9     print(item)
# ---> 10     Book_Data_cleaning['B'] = Book_Data_cleaning['B'].str.replace(str(item), "")
#
# D:\anaconda\lib\site-packages\pandas\core\strings.py in replace(self, pat, repl, n, case, flags)
#    1504     def replace(self, pat, repl, n=-1, case=True, flags=0):
#    1505         result = str_replace(self._data, pat, repl, n=n, case=case,
# ...

# %%
Book_Data_cleaning
# Out:
#       A                                                  B    C  \
# 1   NaN                     Bus 6ESF001TB fails to operate  Bus
# 2   NaN                      Bus EAB001TB fails to operate  NaN
# 3   NaN                      Bus EAA001TB fails to operate  NaN
# 4   NaN                      Bus EAA001TB fails to operate  NaN
# 5   NaN                      Bus EAE001TB fails to operate  NaN
# 6   NaN                      Bus EAW001TB fails to operate  NaN
# 7   NaN                      Bus EAY001TB fails to operate  NaN
# 8   NaN                      Bus ECA001TB fails to operate  NaN
# 9   NaN                      Bus ECB001TB fails to operate  NaN
# 10  NaN                      Bus EDA001TB fails to operate  NaN
# 11  NaN                     Bus EDB001TB  fails to operate  NaN
# 12  NaN                      Bus EDG001TB fails to operate  NaN
# 13  NaN                      Bus EEA001TB fails to operate  NaN
# 14  NaN                                                NaN  NaN
# ...

# %%
# for item in list_C:
# #     item=str(item)
    
#     print(item)
Book_Data_cleaning['B'] = Book_Data_cleaning['B'].str.replace("(", " \(")
Book_Data_cleaning['D'] = Book_Data_cleaning['D'].str.replace("(", " \(")
# Book_Data_cleaning['B'] = Book_Data_cleaning['B'].str.replace(")", "\)")
# Book_Data_cleaning['D'] = Book_Data_cleaning['D'].str.replace(")", "\)")

# %%
Book_Data_cleaning
# Out:
#       A                                                  B    C  \
# 1   NaN                     Bus 6ESF001TB fails to operate  Bus
# 2   NaN                      Bus EAB001TB fails to operate  NaN
# 3   NaN                      Bus EAA001TB fails to operate  NaN
# 4   NaN                      Bus EAA001TB fails to operate  NaN
# 5   NaN                      Bus EAE001TB fails to operate  NaN
# 6   NaN                      Bus EAW001TB fails to operate  NaN
# 7   NaN                      Bus EAY001TB fails to operate  NaN
# 8   NaN                      Bus ECA001TB fails to operate  NaN
# 9   NaN                      Bus ECB001TB fails to operate  NaN
# 10  NaN                      Bus EDA001TB fails to operate  NaN
# 11  NaN                     Bus EDB001TB  fails to operate  NaN
# 12  NaN                      Bus EDG001TB fails to operate  NaN
# 13  NaN                      Bus EEA001TB fails to operate  NaN
# 14  NaN                                                NaN  NaN
# ...

# %%
list_C=list(Book_Data_cleaning['D'])
list_C
Book_Data_cleaning['D']
# Out:
# 1                                             NaN
# 2                                             NaN
# 3                                fails to operate
# 4                                fails to operate
# 5                                fails to operate
# 6                                fails to operate
# 7                                fails to operate
# 8                                fails to operate
# 9                                fails to operate
# 10                               fails to operate
# 11                               fails to operate
# 12                               fails to operate
# 13                               fails to operate
# 14                                            NaN
# 15                                 fails to start
# 16                                            NaN
# 17                                            NaN
# 18     unavailability due to test and maintenance
# 19                                 fails to start
# ...

# %%
for item in Book_Data_cleaning['D']:
#     item=str(item)
    
    print(item)
    Book_Data_cleaning['B'] = Book_Data_cleaning['B'].str.replace(str(item), "")
# Out:
# nan
# nan
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
# nan
#  fails to start
# nan
# nan
# unavailability due to test and maintenance
#  fails to start
#  fails to operate
#  fails to operate \(<1h）
# unavailability due to test and maintenance
#  fails to operate
# nan
#  blockage
#  blockage
#  blockage
#  blockage
#  blockage
#  blockage
# spurious operation
#  large external leakage
# small external leakage
# nan
# nan
# refuses to open
# refuses to open
# refuses to open
# refuses to open
# refuses to open
# refuses to open
#  refuses to close
#  spurious operation
#  refuses to close
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
Book_Data_cleaning
# Out:
#       A                                                  B    C  \
# 1   NaN                                      Bus 6ESF001TB  Bus
# 2   NaN                                       Bus EAB001TB  NaN
# 3   NaN                                       Bus EAA001TB  NaN
# 4   NaN                                       Bus EAA001TB  NaN
# 5   NaN                                       Bus EAE001TB  NaN
# 6   NaN                                       Bus EAW001TB  NaN
# 7   NaN                                       Bus EAY001TB  NaN
# 8   NaN                                       Bus ECA001TB  NaN
# 9   NaN                                       Bus ECB001TB  NaN
# 10  NaN                                       Bus EDA001TB  NaN
# 11  NaN                                      Bus EDB001TB   NaN
# 12  NaN                                       Bus EDG001TB  NaN
# 13  NaN                                       Bus EEA001TB  NaN
# 14  NaN                                                NaN  NaN
# ...

# %%
for item in list_C:
#     item=str(item)
    Book_Data_cleaning['B'] = Book_Data_cleaning['B'].str.replace("\(<1h）", '')
    print(item)
# Out:
# nan
# nan
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
#  fails to operate
# nan
#  fails to start
# nan
# nan
# unavailability due to test and maintenance
#  fails to start
#  fails to operate
#  fails to operate \(<1h）
# unavailability due to test and maintenance
#  fails to operate
# nan
#  blockage
#  blockage
#  blockage
#  blockage
#  blockage
#  blockage
# spurious operation
#  large external leakage
# small external leakage
# nan
# nan
# refuses to open
# refuses to open
# refuses to open
# refuses to open
# refuses to open
# refuses to open
#  refuses to close
#  spurious operation
#  refuses to close
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
Book_Data_cleaning
# Out:
#       A                                                  B    C  \
# 1   NaN                                      Bus 6ESF001TB  Bus
# 2   NaN                                       Bus EAB001TB  NaN
# 3   NaN                                       Bus EAA001TB  NaN
# 4   NaN                                       Bus EAA001TB  NaN
# 5   NaN                                       Bus EAE001TB  NaN
# 6   NaN                                       Bus EAW001TB  NaN
# 7   NaN                                       Bus EAY001TB  NaN
# 8   NaN                                       Bus ECA001TB  NaN
# 9   NaN                                       Bus ECB001TB  NaN
# 10  NaN                                       Bus EDA001TB  NaN
# 11  NaN                                      Bus EDB001TB   NaN
# 12  NaN                                       Bus EDG001TB  NaN
# 13  NaN                                       Bus EEA001TB  NaN
# 14  NaN                                                NaN  NaN
# ...
